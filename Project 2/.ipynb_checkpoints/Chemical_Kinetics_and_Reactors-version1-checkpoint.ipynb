# %%
import cantera as ct    # import cantera
import math             # import math (sqrt, exp, etc.)
from scipy.integrate import solve_ivp  # solves ODE (initial value problems)
import scipy.integrate as integrate
import matplotlib.pyplot as plt      # does matlab-like plotting
import numpy as np                    # does a bunch of array stuff

# %%
gas = ct.Solution('chem.cti')

# %% [markdown]
# A list of all the reaction equations can be listed with the
#
# ``` python
# reaction_equations()
# ```
#
# function.

# %%
gas.reaction_equations()
# Out:
# ['H + O2 => O + OH',
#  'O + OH => H + O2',
#  'H2 + O => H + OH',
#  'H + OH => H2 + O',
#  'H2 + OH => H + H2O',
#  'H + H2O => H2 + OH',
#  'H2O + O => 2 OH',
#  '2 OH => H2O + O',
#  'H2 + M => 2 H + M',
#  '2 H + M => H2 + M',
#  'O2 + M => 2 O + M',
#  '2 O + M => O2 + M',
#  'OH + M => H + O + M',
#  'H + O + M => OH + M',
#  'H2O + M => H + OH + M',
#  'H + OH + M => H2O + M',
#  'H + O2 (+M) <=> HO2 (+M)',
#  'H + HO2 => H2 + O2',
#  'H2 + O2 => H + HO2',
#  'H + HO2 => 2 OH',
#  '2 OH => H + HO2',
#  'HO2 + O => O2 + OH',
#  'O2 + OH => HO2 + O',
#  'HO2 + OH => H2O + O2',
#  'H2O + O2 => HO2 + OH',
#  'H2O2 + O2 => 2 HO2',
#  '2 HO2 => H2O2 + O2',
#  'H2O2 + O2 => 2 HO2',
#  '2 HO2 => H2O2 + O2',
#  'H2O2 (+M) <=> 2 OH (+M)',
#  'H + H2O2 => H2O + OH',
#  'H2O + OH => H + H2O2',
#  'H + H2O2 => H2 + HO2',
#  'H2 + HO2 => H + H2O2',
#  'H2O2 + O => HO2 + OH',
#  'HO2 + OH => H2O2 + O',
#  'H2O2 + OH => H2O + HO2',
#  'H2O + HO2 => H2O2 + OH',
#  'H2O2 + OH => H2O + HO2',
#  'H2O + HO2 => H2O2 + OH',
#  'CO + O (+M) <=> CO2 (+M)',
#  'CO + O2 => CO2 + O',
#  'CO2 + O => CO + O2',
#  'CO + OH => CO2 + H',
#  'CO2 + H => CO + OH',
#  'CO + HO2 => CO2 + OH',
#  'CO2 + OH => CO + HO2',
#  'HCO + M => CO + H + M',
#  'CO + H + M => HCO + M',
#  'HCO + O2 => CO + HO2',
#  'CO + HO2 => HCO + O2',
#  'H + HCO => CO + H2',
#  'CO + H2 => H + HCO',
#  'HCO + O => CO + OH',
#  'CO + OH => HCO + O',
#  'HCO + O => CO2 + H',
#  'CO2 + H => HCO + O',
#  'HCO + OH => CO + H2O',
#  'CO + H2O => HCO + OH',
#  'CH3 + HCO => CH4 + CO',
#  'CH4 + CO => CH3 + HCO',
#  'HCO + HO2 => CH2O + O2',
#  'CH2O + O2 => HCO + HO2',
#  'HCO + HO2 => CO2 + H + OH',
#  'CH2O + CO => 2 HCO',
#  '2 HCO => CH2O + CO',
#  '2 HCO => 2 CO + H2',
#  'H + HCO (+M) <=> CH2O (+M)',
#  'CO + H2 (+M) <=> CH2O (+M)',
#  'CH2O + OH => H2O + HCO',
#  'H2O + HCO => CH2O + OH',
#  'CH2O + H => H2 + HCO',
#  'H2 + HCO => CH2O + H',
#  'CH2O + O => HCO + OH',
#  'HCO + OH => CH2O + O',
#  'CH2O + CH3 => CH4 + HCO',
#  'CH4 + HCO => CH2O + CH3',
#  'CH2O + HO2 => H2O2 + HCO',
#  'H2O2 + HCO => CH2O + HO2',
#  'HOCH2O => CH2O + OH',
#  'CH2O + OH => HOCH2O',
#  'HOCH2O => H + HOCHO',
#  'H + HOCHO => HOCH2O',
#  'HOCHO => CO + H2O',
#  'CO + H2O => HOCHO',
#  'HOCHO => CO2 + H2',
#  'CO2 + H2 => HOCHO',
#  'HOCHO => HCO + OH',
#  'HCO + OH => HOCHO',
#  'HOCHO + OH => CO2 + H + H2O',
#  'HOCHO + OH => CO + H2O + OH',
#  'H + HOCHO => CO2 + H + H2',
#  'H + HOCHO => CO + H2 + OH',
#  'CH3 + HOCHO => CH4 + CO + OH',
#  'HO2 + HOCHO => CO + H2O2 + OH',
#  'HOCHO + O => CO + 2 OH',
#  'CH3O (+M) <=> CH2O + H (+M)',
#  'CH3O + O2 => CH2O + HO2',
#  'CH2O + HO2 => CH3O + O2',
#  'CH2O + CH3O => CH3OH + HCO',
#  'CH3OH + HCO => CH2O + CH3O',
#  'CH3O + CH4 => CH3 + CH3OH',
#  'CH3 + CH3OH => CH3O + CH4',
#  'CH3 + CH3O => CH2O + CH4',
#  'CH2O + CH4 => CH3 + CH3O',
#  'CH3O + H => CH2O + H2',
#  'CH2O + H2 => CH3O + H',
#  'CH3O + HO2 => CH2O + H2O2',
#  'CH2O + H2O2 => CH3O + HO2',
#  'CH2O + H (+M) <=> CH2OH (+M)',
#  'CH2OH + O2 => CH2O + HO2',
#  'CH2O + HO2 => CH2OH + O2',
#  'CH2OH + O2 => CH2O + HO2',
#  'CH2O + HO2 => CH2OH + O2',
#  'CH2OH + H => CH2O + H2',
#  'CH2O + H2 => CH2OH + H',
#  'CH2OH + HO2 => CH2O + H2O2',
#  'CH2O + H2O2 => CH2OH + HO2',
#  'CH2OH + HCO => 2 CH2O',
#  '2 CH2O => CH2OH + HCO',
#  'CH2OH + CH3O => CH2O + CH3OH',
#  'CH2O + CH3OH => CH2OH + CH3O',
#  'CH2O + CH2OH => CH3OH + HCO',
#  'CH3OH + HCO => CH2O + CH2OH',
#  'CH2OH + OH => CH2O + H2O',
#  'CH2O + H2O => CH2OH + OH',
#  'CH2OH + O => CH2O + OH',
#  'CH2O + OH => CH2OH + O',
#  'CH2O + CH3OH => 2 CH2OH',
#  '2 CH2OH => CH2O + CH3OH',
#  'CH2OH + HO2 => HOCH2O + OH',
#  'HOCH2O + OH => CH2OH + HO2',
#  'CH3OH (+M) <=> CH3 + OH (+M)',
#  'CH3OH (+M) <=> CH2OH + H (+M)',
#  'CH3OH + H => CH3O + H2',
#  'CH3O + H2 => CH3OH + H',
#  'CH3OH + H => CH2OH + H2',
#  'CH2OH + H2 => CH3OH + H',
#  'CH3OH + O => CH2OH + OH',
#  'CH2OH + OH => CH3OH + O',
#  'CH3OH + OH => CH3O + H2O',
#  'CH3O + H2O => CH3OH + OH',
#  'CH3OH + OH => CH2OH + H2O',
#  'CH2OH + H2O => CH3OH + OH',
#  'CH3OH + O2 => CH2OH + HO2',
#  'CH2OH + HO2 => CH3OH + O2',
#  'CH3OH + HO2 => CH2OH + H2O2',
#  'CH2OH + H2O2 => CH3OH + HO2',
#  'CH3 + CH3OH => CH2OH + CH4',
#  'CH2OH + CH4 => CH3 + CH3OH',
#  'CH3O + CH3OH => CH2OH + CH3OH',
#  'CH2OH + CH3OH => CH3O + CH3OH',
#  'CH2O + CH3OH => 2 CH3O',
#  '2 CH3O => CH2O + CH3OH',
#  'CH3 + H (+M) <=> CH4 (+M)',
#  'CH4 + H => CH3 + H2',
#  'CH3 + H2 => CH4 + H',
#  'CH4 + OH => CH3 + H2O',
#  'CH3 + H2O => CH4 + OH',
#  'CH4 + O => CH3 + OH',
#  'CH3 + OH => CH4 + O',
#  'CH4 + HO2 => CH3 + H2O2',
#  'CH3 + H2O2 => CH4 + HO2',
#  'CH2 + CH4 => 2 CH3',
#  '2 CH3 => CH2 + CH4',
#  'CH3 + OH => CH2O + H2',
#  'CH2O + H2 => CH3 + OH',
#  'CH3 + OH => CH2(S) + H2O',
#  'CH2(S) + H2O => CH3 + OH',
#  'CH3 + OH => CH3O + H',
#  'CH3O + H => CH3 + OH',
#  'CH3 + OH => CH2OH + H',
#  'CH2OH + H => CH3 + OH',
#  'CH3 + OH => CH2 + H2O',
#  'CH2 + H2O => CH3 + OH',
#  'CH3 + HO2 => CH3O + OH',
#  'CH3O + OH => CH3 + HO2',
#  'CH3 + HO2 => CH4 + O2',
#  'CH4 + O2 => CH3 + HO2',
#  'CH3 + O => CH2O + H',
#  'CH2O + H => CH3 + O',
#  'CH3 + O2 => CH3O + O',
#  'CH3O + O => CH3 + O2',
#  'CH3 + O2 => CH2O + OH',
#  'CH2O + OH => CH3 + O2',
#  'CH3 + O2 (+M) <=> CH3O2 (+M)',
#  'CH2O + CH3O2 => CH3O2H + HCO',
#  'CH3O2H + HCO => CH2O + CH3O2',
#  'CH3O2 + CH4 => CH3 + CH3O2H',
#  'CH3 + CH3O2H => CH3O2 + CH4',
#  'CH3O2 + CH3OH => CH2OH + CH3O2H',
#  'CH2OH + CH3O2H => CH3O2 + CH3OH',
#  'CH3 + CH3O2 => 2 CH3O',
#  '2 CH3O => CH3 + CH3O2',
#  'CH3O2 + HO2 => CH3O2H + O2',
#  'CH3O2H + O2 => CH3O2 + HO2',
#  '2 CH3O2 => CH2O + CH3OH + O2',
#  '2 CH3O2 => 2 CH3O + O2',
#  'CH3O2 + H => CH3O + OH',
#  'CH3O + OH => CH3O2 + H',
#  'CH3O2 + O => CH3O + O2',
#  'CH3O + O2 => CH3O2 + O',
#  'CH3O2 + OH => CH3OH + O2',
#  'CH3OH + O2 => CH3O2 + OH',
#  'CH3O2H => CH3O + OH',
#  'CH3O + OH => CH3O2H',
#  'CH2(S) => CH2',
#  'CH2 => CH2(S)',
#  'CH2(S) + CH4 => 2 CH3',
#  '2 CH3 => CH2(S) + CH4',
#  'CH2(S) + O2 => CO + H + OH',
#  'CH2(S) + H2 => CH3 + H',
#  'CH3 + H => CH2(S) + H2',
#  'CH2(S) + H => CH2 + H',
#  'CH2 + H => CH2(S) + H',
#  'CH2(S) + O => CO + 2 H',
#  'CH2(S) + OH => CH2O + H',
#  'CH2O + H => CH2(S) + OH',
#  'CH2(S) + CO2 => CH2O + CO',
#  'CH2O + CO => CH2(S) + CO2',
#  'CH2 + H (+M) <=> CH3 (+M)',
#  'CH2 + O2 => CH2O + O',
#  'CH2O + O => CH2 + O2',
#  'CH2 + O2 => CO2 + 2 H',
#  'CH2 + O2 => CO + H + OH',
#  'CH2 + O => CO + 2 H',
#  '2 CH3 (+M) <=> C2H6 (+M)',
#  'C2H5 + H (+M) <=> C2H6 (+M)',
#  'C2H6 + H => C2H5 + H2',
#  'C2H5 + H2 => C2H6 + H',
#  'C2H6 + O => C2H5 + OH',
#  'C2H5 + OH => C2H6 + O',
#  'C2H6 + OH => C2H5 + H2O',
#  'C2H5 + H2O => C2H6 + OH',
#  'C2H6 + O2 => C2H5 + HO2',
#  'C2H5 + HO2 => C2H6 + O2',
#  'C2H6 + CH3 => C2H5 + CH4',
#  'C2H5 + CH4 => C2H6 + CH3',
#  'C2H6 + HO2 => C2H5 + H2O2',
#  'C2H5 + H2O2 => C2H6 + HO2',
#  'C2H6 + CH3O2 => C2H5 + CH3O2H',
#  'C2H5 + CH3O2H => C2H6 + CH3O2',
#  'C2H6 + CH3O => C2H5 + CH3OH',
#  'C2H5 + CH3OH => C2H6 + CH3O',
#  'C2H6 + CH2(S) => C2H5 + CH3',
#  'C2H5 + CH3 => C2H6 + CH2(S)',
#  'C2H4 + H (+M) <=> C2H5 (+M)',
#  'CH3O2 + H2 => CH3O2H + H',
#  'CH3O2H + H => CH3O2 + H2',
#  'C2H5O2 + H2 => C2H5O2H + H',
#  'C2H5O2H + H => C2H5O2 + H2',
#  'C2H3 + C2H5 => 2 C2H4',
#  '2 C2H4 => C2H3 + C2H5',
#  'C2H5 + CH3 => C2H4 + CH4',
#  'C2H4 + CH4 => C2H5 + CH3',
#  'C2H5 + H => 2 CH3',
#  '2 CH3 => C2H5 + H',
#  'C2H5 + H => C2H4 + H2',
#  'C2H4 + H2 => C2H5 + H',
#  'C2H5 + O => CH3CHO + H',
#  'CH3CHO + H => C2H5 + O',
#  'C2H5 + HO2 => C2H5O + OH',
#  'C2H5O + OH => C2H5 + HO2',
#  'C2H5 + CH3O2 => C2H5O + CH3O',
#  'C2H5O + CH3O => C2H5 + CH3O2',
#  'C2H5O + O2 => CH3CHO + HO2',
#  'CH3CHO + HO2 => C2H5O + O2',
#  'C2H5O => CH2O + CH3',
#  'CH2O + CH3 => C2H5O',
#  'C2H5O => CH3CHO + H',
#  'CH3CHO + H => C2H5O',
#  'C2H5O2 => C2H5 + O2',
#  'C2H5 + O2 => C2H5O2',
#  'C2H5O2 + CH2O => C2H5O2H + HCO',
#  'C2H5O2H + HCO => C2H5O2 + CH2O',
#  'C2H5O2 + CH4 => C2H5O2H + CH3',
#  'C2H5O2H + CH3 => C2H5O2 + CH4',
#  'C2H5O2 + CH3OH => C2H5O2H + CH2OH',
#  'C2H5O2H + CH2OH => C2H5O2 + CH3OH',
#  'C2H5O2 + HO2 => C2H5O2H + O2',
#  'C2H5O2H + O2 => C2H5O2 + HO2',
#  'C2H5O2 + C2H6 => C2H5 + C2H5O2H',
#  'C2H5 + C2H5O2H => C2H5O2 + C2H6',
#  'C2H5O2H => C2H5O + OH',
#  'C2H5O + OH => C2H5O2H',
#  'C2H5 + O2 => C2H4 + HO2',
#  'C2H4 + HO2 => C2H5 + O2',
#  'C2H5 + O2 => C2H4 + HO2',
#  'C2H4 + HO2 => C2H5 + O2',
#  'C2H5 + O2 => CH3CHO + OH',
#  'CH3CHO + OH => C2H5 + O2',
#  'C2H5O2 => CH3CHO + OH',
#  'CH3CHO + OH => C2H5O2',
#  'C2H5O2 => C2H4 + HO2',
#  'C2H4 + HO2 => C2H5O2',
#  'C2H3O1-2 => CH3CO',
#  'CH3CO => C2H3O1-2',
#  'C2H3O1-2 => CH2CHO',
#  'CH2CHO => C2H3O1-2',
#  'CH3CHO => CH3 + HCO',
#  'CH3 + HCO => CH3CHO',
#  'CH3CHO + H => CH3CO + H2',
#  'CH3CO + H2 => CH3CHO + H',
#  'CH3CHO + O => CH3CO + OH',
#  'CH3CO + OH => CH3CHO + O',
#  'CH3CHO + OH => CH3CO + H2O',
#  'CH3CO + H2O => CH3CHO + OH',
#  'CH3CHO + O2 => CH3CO + HO2',
#  'CH3CO + HO2 => CH3CHO + O2',
#  'CH3 + CH3CHO => CH3CO + CH4',
#  'CH3CO + CH4 => CH3 + CH3CHO',
#  'CH3CHO + HO2 => CH3CO + H2O2',
#  'CH3CO + H2O2 => CH3CHO + HO2',
#  'CH3CHO + CH3O2 => CH3CO + CH3O2H',
#  'CH3CO + CH3O2H => CH3CHO + CH3O2',
#  'CH3CHO + OH => CH3 + HOCHO',
#  'CH3 + HOCHO => CH3CHO + OH',
#  'CH3CHO + OH => CH2CHO + H2O',
#  'CH2CHO + H2O => CH3CHO + OH',
#  'CH3CO (+M) <=> CH3 + CO (+M)',
#  'CH3CO + H => CH2CO + H2',
#  'CH2CO + H2 => CH3CO + H',
#  'CH3CO + O => CH2CO + OH',
#  'CH2CO + OH => CH3CO + O',
#  'CH3 + CH3CO => CH2CO + CH4',
#  'CH2CO + CH4 => CH3 + CH3CO',
#  'CH3CO3 => CH3CO + O2',
#  'CH3CO + O2 => CH3CO3',
#  'CH2CHO => CH2CO + H',
#  'CH2CO + H => CH2CHO',
#  'CH2CHO + O2 => CH2O + CO + OH',
#  'CH2 + CO (+M) <=> CH2CO (+M)',
#  'CH2CO + H => CH3 + CO',
#  'CH3 + CO => CH2CO + H',
#  'CH2CO + H => H2 + HCCO',
#  'H2 + HCCO => CH2CO + H',
#  'CH2CO + O => CH2 + CO2',
#  'CH2 + CO2 => CH2CO + O',
#  'CH2CO + O => HCCO + OH',
#  'HCCO + OH => CH2CO + O',
#  'CH2CO + OH => H2O + HCCO',
#  'H2O + HCCO => CH2CO + OH',
#  'CH2CO + OH => CH2OH + CO',
#  'CH2OH + CO => CH2CO + OH',
#  'CH2(S) + CH2CO => C2H4 + CO',
#  'C2H4 + CO => CH2(S) + CH2CO',
#  'HCCO + OH => 2 CO + H2',
#  'H + HCCO => CH2(S) + CO',
#  'CH2(S) + CO => H + HCCO',
#  'HCCO + O => 2 CO + H',
#  'HCCO + O2 => 2 CO + OH',
#  'C2H3 + H (+M) <=> C2H4 (+M)',
#  'C2H4 (+M) <=> C2H2 + H2 (+M)',
#  'C2H4 + H => C2H3 + H2',
#  'C2H3 + H2 => C2H4 + H',
#  'C2H4 + O => CH3 + HCO',
#  'CH3 + HCO => C2H4 + O',
#  'C2H4 + O => CH2CHO + H',
#  'CH2CHO + H => C2H4 + O',
#  'C2H4 + OH => C2H3 + H2O',
#  'C2H3 + H2O => C2H4 + OH',
#  'C2H4 + CH3 => C2H3 + CH4',
#  'C2H3 + CH4 => C2H4 + CH3',
#  'C2H4 + O2 => C2H3 + HO2',
#  'C2H3 + HO2 => C2H4 + O2',
#  'C2H4 + CH3O <=> C2H3 + CH3OH',
#  'C2H4 + CH3O2 <=> C2H3 + CH3O2H',
#  'C2H4 + C2H5O2 <=> C2H3 + C2H5O2H',
#  'CH2(S) + CH3 => C2H4 + H',
#  'C2H4 + H => CH2(S) + CH3',
#  'C2H2 + H (+M) <=> C2H3 (+M)',
#  'C2H3 + O2 => C2H2 + HO2',
#  'C2H2 + HO2 => C2H3 + O2',
#  'C2H3 + O2 => CH2O + HCO',
#  'CH2O + HCO => C2H3 + O2',
#  'C2H3 + O2 => CH2CHO + O',
#  'CH2CHO + O => C2H3 + O2',
#  'C2H3 + CH3 => C2H2 + CH4',
#  'C2H2 + CH4 => C2H3 + CH3',
#  'C2H3 + H => C2H2 + H2',
#  'C2H2 + H2 => C2H3 + H',
#  'C2H3 + OH => C2H2 + H2O',
#  'C2H2 + H2O => C2H3 + OH',
#  'C2H2 + O2 => HCCO + OH',
#  'HCCO + OH => C2H2 + O2',
#  'C2H2 + O => CH2 + CO',
#  'CH2 + CO => C2H2 + O',
#  'C2H2 + O => H + HCCO',
#  'H + HCCO => C2H2 + O',
#  'C2H2 + OH => CH2CO + H',
#  'CH2CO + H => C2H2 + OH',
#  'C2H2 + OH => CH3 + CO',
#  'CH3 + CO => C2H2 + OH',
#  'CH3COCH3 (+M) <=> CH3 + CH3CO (+M)',
#  'CH3COCH3 + OH => CH3COCH2 + H2O',
#  'CH3COCH2 + H2O => CH3COCH3 + OH',
#  'CH3COCH3 + H => CH3COCH2 + H2',
#  'CH3COCH2 + H2 => CH3COCH3 + H',
#  'CH3COCH3 + O => CH3COCH2 + OH',
#  'CH3COCH2 + OH => CH3COCH3 + O',
#  'CH3 + CH3COCH3 => CH3COCH2 + CH4',
#  'CH3COCH2 + CH4 => CH3 + CH3COCH3',
#  'CH3COCH3 + CH3O => CH3COCH2 + CH3OH',
#  'CH3COCH2 + CH3OH => CH3COCH3 + CH3O',
#  'CH3COCH3 + O2 => CH3COCH2 + HO2',
#  'CH3COCH2 + HO2 => CH3COCH3 + O2',
#  'CH3COCH3 + HO2 => CH3COCH2 + H2O2',
#  'CH3COCH2 + H2O2 => CH3COCH3 + HO2',
#  'CH3COCH3 + CH3O2 => CH3COCH2 + CH3O2H',
#  'CH3COCH2 + CH3O2H => CH3COCH3 + CH3O2',
#  'CH3COCH2 => CH2CO + CH3',
#  'CH2CO + CH3 => CH3COCH2',
#  'CH3COCH2O2 => CH3COCH2 + O2',
#  'CH3COCH2 + O2 => CH3COCH2O2',
#  'CH3COCH2O2 + CH3COCH3 => CH3COCH2 + CH3COCH2O2H',
#  'CH3COCH2 + CH3COCH2O2H => CH3COCH2O2 + CH3COCH3',
#  'CH2O + CH3COCH2O2 => CH3COCH2O2H + HCO',
#  'CH3COCH2O2H + HCO => CH2O + CH3COCH2O2',
#  'CH3COCH2O2 + HO2 => CH3COCH2O2H + O2',
#  'CH3COCH2O2H => CH3COCH2O + OH',
#  'CH3COCH2O + OH => CH3COCH2O2H',
#  'CH3COCH2O => CH2O + CH3CO',
#  'CH2O + CH3CO => CH3COCH2O',
#  'C2H3CHO => C2H3 + HCO',
#  'C2H3 + HCO => C2H3CHO',
#  'C2H3CHO + H => C2H3CO + H2',
#  'C2H3CO + H2 => C2H3CHO + H',
#  'C2H3CHO + O => C2H3CO + OH',
#  'C2H3CO + OH => C2H3CHO + O',
#  'C2H3CHO + OH => C2H3CO + H2O',
#  'C2H3CO + H2O => C2H3CHO + OH',
#  'C2H3CHO + O2 => C2H3CO + HO2',
#  'C2H3CO + HO2 => C2H3CHO + O2',
#  'C2H3CHO + HO2 => C2H3CO + H2O2',
#  'C2H3CO + H2O2 => C2H3CHO + HO2',
#  'C2H3CHO + CH3 => C2H3CO + CH4',
#  'C2H3CO + CH4 => C2H3CHO + CH3',
#  'C2H3 + C2H3CHO => C2H3CO + C2H4',
#  'C2H3CO + C2H4 => C2H3 + C2H3CHO',
#  'C2H3CHO + CH3O => C2H3CO + CH3OH',
#  'C2H3CO + CH3OH => C2H3CHO + CH3O',
#  'C2H3CHO + CH3O2 => C2H3CO + CH3O2H',
#  'C2H3CO + CH3O2H => C2H3CHO + CH3O2',
#  'C2H3CO => C2H3 + CO',
#  'C2H3 + CO => C2H3CO',
#  'C2H5CHO => C2H5 + HCO',
#  'C2H5 + HCO => C2H5CHO',
#  'C2H5CHO + H => C2H5CO + H2',
#  'C2H5CO + H2 => C2H5CHO + H',
#  'C2H5CHO + O => C2H5CO + OH',
#  'C2H5CO + OH => C2H5CHO + O',
#  'C2H5CHO + OH => C2H5CO + H2O',
#  'C2H5CO + H2O => C2H5CHO + OH',
#  'C2H5CHO + CH3 => C2H5CO + CH4',
#  'C2H5CO + CH4 => C2H5CHO + CH3',
#  'C2H5CHO + HO2 => C2H5CO + H2O2',
#  'C2H5CO + H2O2 => C2H5CHO + HO2',
#  'C2H5CHO + CH3O => C2H5CO + CH3OH',
#  'C2H5CO + CH3OH => C2H5CHO + CH3O',
#  'C2H5CHO + CH3O2 => C2H5CO + CH3O2H',
#  'C2H5CO + CH3O2H => C2H5CHO + CH3O2',
#  'C2H5 + C2H5CHO => C2H5CO + C2H6',
#  'C2H5CO + C2H6 => C2H5 + C2H5CHO',
#  'C2H5CHO + C2H5O2 => C2H5CO + C2H5O2H',
#  'C2H5CO + C2H5O2H => C2H5CHO + C2H5O2',
#  'C2H5CHO + O2 => C2H5CO + HO2',
#  'C2H5CO + HO2 => C2H5CHO + O2',
#  'C2H3 + C2H5CHO => C2H4 + C2H5CO',
#  'C2H4 + C2H5CO => C2H3 + C2H5CHO',
#  'C2H5CO => C2H5 + CO',
#  'C2H5 + CO => C2H5CO',
#  'IC3H7 => C3H6 + H',
#  'C3H6 + H => IC3H7',
#  'H + IC3H7 => C2H5 + CH3',
#  'C2H5 + CH3 => H + IC3H7',
#  'IC3H7 + O2 => C3H6 + HO2',
#  'C3H6 + HO2 => IC3H7 + O2',
#  'IC3H7 + OH => C3H6 + H2O',
#  'C3H6 + H2O => IC3H7 + OH',
#  'IC3H7 + O => CH3COCH3 + H',
#  'CH3COCH3 + H => IC3H7 + O',
#  'IC3H7 + O => CH3 + CH3CHO',
#  'CH3 + CH3CHO => IC3H7 + O',
#  'NC3H7 <=> C2H4 + CH3',
#  'NC3H7 <=> C3H6 + H',
#  'NC3H7 + O2 => C3H6 + HO2',
#  'C3H6 + HO2 => NC3H7 + O2',
#  'C2H5CHO + C3H5-A => C2H5CO + C3H6',
#  'C2H5CO + C3H6 => C2H5CHO + C3H5-A',
#  'C3H6 => C2H3 + CH3',
#  'C2H3 + CH3 => C3H6',
#  'C3H6 => C3H5-A + H',
#  'C3H5-A + H => C3H6',
#  'C3H6 => C3H5-S + H',
#  'C3H5-S + H => C3H6',
#  'C3H6 => C3H5-T + H',
#  'C3H5-T + H => C3H6',
#  'C3H6 + O => C2H5 + HCO',
#  'C2H5 + HCO => C3H6 + O',
#  'C3H6 + O => CH2CO + CH3 + H',
#  'C3H6 + O => CH3CHCO + 2 H',
#  'C3H6 + O => C3H5-A + OH',
#  'C3H5-A + OH => C3H6 + O',
#  'C3H6 + O => C3H5-S + OH',
#  'C3H5-S + OH => C3H6 + O',
#  'C3H6 + O => C3H5-T + OH',
#  'C3H5-T + OH => C3H6 + O',
#  'C3H6 + OH => C3H5-A + H2O',
#  'C3H5-A + H2O => C3H6 + OH',
#  'C3H6 + OH => C3H5-S + H2O',
#  'C3H5-S + H2O => C3H6 + OH',
#  'C3H6 + OH => C3H5-T + H2O',
#  'C3H5-T + H2O => C3H6 + OH',
#  'C3H6 + HO2 => C3H5-A + H2O2',
#  'C3H5-A + H2O2 => C3H6 + HO2',
#  'C3H6 + HO2 => C3H5-S + H2O2',
#  'C3H5-S + H2O2 => C3H6 + HO2',
#  'C3H6 + HO2 => C3H5-T + H2O2',
#  'C3H5-T + H2O2 => C3H6 + HO2',
#  'C3H6 + H => C3H5-A + H2',
#  'C3H5-A + H2 => C3H6 + H',
#  'C3H6 + H => C3H5-S + H2',
#  'C3H5-S + H2 => C3H6 + H',
#  'C3H6 + H => C3H5-T + H2',
#  'C3H5-T + H2 => C3H6 + H',
#  'C3H6 + H => C2H4 + CH3',
#  'C2H4 + CH3 => C3H6 + H',
#  'C3H6 + O2 => C3H5-A + HO2',
#  'C3H5-A + HO2 => C3H6 + O2',
#  'C3H6 + O2 => C3H5-S + HO2',
#  'C3H5-S + HO2 => C3H6 + O2',
#  'C3H6 + O2 => C3H5-T + HO2',
#  'C3H5-T + HO2 => C3H6 + O2',
#  'C3H6 + CH3 => C3H5-A + CH4',
#  'C3H5-A + CH4 => C3H6 + CH3',
#  'C3H6 + CH3 => C3H5-S + CH4',
#  'C3H5-S + CH4 => C3H6 + CH3',
#  'C3H6 + CH3 => C3H5-T + CH4',
#  'C3H5-T + CH4 => C3H6 + CH3',
#  'C2H5 + C3H6 => C2H6 + C3H5-A',
#  'C2H6 + C3H5-A => C2H5 + C3H6',
#  'C3H6 + CH3O2 => C3H5-A + CH3O2H',
#  'C3H5-A + CH3O2H => C3H6 + CH3O2',
#  'C2H5O2 + C3H6 => C2H5O2H + C3H5-A',
#  'C2H5O2H + C3H5-A => C2H5O2 + C3H6',
#  'C3H5-A => C2H2 + CH3',
#  'C2H2 + CH3 => C3H5-A',
#  'C3H5-A => C3H4-A + H',
#  'C3H4-A + H => C3H5-A',
#  'C3H5-A + HO2 => C3H5O + OH',
#  'C3H5O + OH => C3H5-A + HO2',
#  'C3H5-A + CH3O2 => C3H5O + CH3O',
#  'C3H5O + CH3O => C3H5-A + CH3O2',
#  'C3H5-A + H => C3H4-A + H2',
#  'C3H4-A + H2 => C3H5-A + H',
#  'C3H5-A + CH3 => C3H4-A + CH4',
#  'C3H4-A + CH4 => C3H5-A + CH3',
#  'C2H5 + C3H5-A => C2H6 + C3H4-A',
#  'C2H6 + C3H4-A => C2H5 + C3H5-A',
#  'C2H5 + C3H5-A => C2H4 + C3H6',
#  'C2H4 + C3H6 => C2H5 + C3H5-A',
#  'C2H3 + C3H5-A => C2H4 + C3H4-A',
#  'C2H4 + C3H4-A => C2H3 + C3H5-A',
#  'C3H4-A + C3H6 => 2 C3H5-A',
#  '2 C3H5-A => C3H4-A + C3H6',
#  'C3H5-A + O2 => C3H4-A + HO2',
#  'C3H4-A + HO2 => C3H5-A + O2',
#  'C3H5-A + O2 => CH2CHO + CH2O',
#  'CH2CHO + CH2O => C3H5-A + O2',
#  'C3H5-A + O2 => C2H3CHO + OH',
#  'C2H3CHO + OH => C3H5-A + O2',
#  'C3H5-A + O2 => C2H2 + CH2O + OH',
#  'C3H5-S => C2H2 + CH3',
#  'C2H2 + CH3 => C3H5-S',
#  'C3H5-S => C3H4-P + H',
#  'C3H4-P + H => C3H5-S',
#  'C3H5-S + O2 => CH3CHO + HCO',
#  'CH3CHO + HCO => C3H5-S + O2',
#  'C3H5-S + H => C3H4-A + H2',
#  'C3H4-A + H2 => C3H5-S + H',
#  'C3H5-S + CH3 => C3H4-A + CH4',
#  'C3H4-A + CH4 => C3H5-S + CH3',
#  'C3H5-T => C2H2 + CH3',
#  'C2H2 + CH3 => C3H5-T',
#  'C3H5-T => C3H4-A + H',
#  'C3H4-A + H => C3H5-T',
#  'C3H5-T => C3H4-P + H',
#  'C3H4-P + H => C3H5-T',
#  'C3H5-T + O2 => C3H4-A + HO2',
#  'C3H4-A + HO2 => C3H5-T + O2',
#  'C3H5-T + O2 => CH3COCH2 + O',
#  'CH3COCH2 + O => C3H5-T + O2',
#  'C3H5-T + O2 => CH2O + CH3CO',
#  'CH2O + CH3CO => C3H5-T + O2',
#  'C3H5-T + H => C3H4-P + H2',
#  'C3H4-P + H2 => C3H5-T + H',
#  'C3H5-T + CH3 => C3H4-P + CH4',
#  'C3H4-P + CH4 => C3H5-T + CH3',
#  'C3H4-A + M => C3H3 + H + M',
#  'C3H3 + H + M => C3H4-A + M',
#  'C3H4-A => C3H4-P',
#  'C3H4-P => C3H4-A',
#  'C3H4-A + O2 => C3H3 + HO2',
#  'C3H3 + HO2 => C3H4-A + O2',
#  'C3H4-A + HO2 => CH2 + CH2CO + OH',
#  'CH2 + CH2CO + OH => C3H4-A + HO2',
#  'C3H4-A + OH => CH2CO + CH3',
#  'CH2CO + CH3 => C3H4-A + OH',
#  'C3H4-A + OH => C3H3 + H2O',
#  'C3H3 + H2O => C3H4-A + OH',
#  'C3H4-A + O => C2H4 + CO',
#  'C2H4 + CO => C3H4-A + O',
#  'C3H4-A + O => C2H2 + CH2O',
#  'C2H2 + CH2O => C3H4-A + O',
#  'C3H4-A + H => C3H3 + H2',
#  'C3H3 + H2 => C3H4-A + H',
#  'C3H4-A + CH3 => C3H3 + CH4',
#  'C3H3 + CH4 => C3H4-A + CH3',
#  'C3H4-A + C3H5-A => C3H3 + C3H6',
#  'C3H3 + C3H6 => C3H4-A + C3H5-A',
#  'C3H4-P + M => C3H3 + H + M',
#  'C3H3 + H + M => C3H4-P + M',
#  'C3H4-P + O2 => CH2 + HCCO + OH',
#  'CH2 + HCCO + OH => C3H4-P + O2',
#  'C3H4-P + O2 => C3H3 + HO2',
#  'C3H3 + HO2 => C3H4-P + O2',
#  'C3H4-P + HO2 => C2H4 + CO + OH',
#  'C2H4 + CO + OH => C3H4-P + HO2',
#  'C3H4-P + OH => C3H3 + H2O',
#  'C3H3 + H2O => C3H4-P + OH',
#  'C3H4-P + OH => CH2CO + CH3',
#  'CH2CO + CH3 => C3H4-P + OH',
#  'C3H4-P + O => C2H3 + HCO',
#  'C2H3 + HCO => C3H4-P + O',
#  'C3H4-P + O => CH3 + HCCO',
#  'CH3 + HCCO => C3H4-P + O',
#  'C3H4-P + O => CH2 + H + HCCO',
#  'C3H4-P + O => C3H3 + OH',
#  'C3H3 + OH => C3H4-P + O',
#  'C3H4-P + H => C3H3 + H2',
#  'C3H3 + H2 => C3H4-P + H',
#  'C3H4-P + CH3 => C3H3 + CH4',
#  'C3H3 + CH4 => C3H4-P + CH3',
#  'C2H3 + C3H4-P => C2H4 + C3H3',
#  'C2H4 + C3H3 => C2H3 + C3H4-P',
#  'C3H4-P + C3H5-A => C3H3 + C3H6',
#  'C3H3 + C3H6 => C3H4-P + C3H5-A',
#  'C3H3 + OH => C3H2 + H2O',
#  'C3H2 + H2O => C3H3 + OH',
#  'C3H3 + O2 => CH2CO + HCO',
#  'CH2CO + HCO => C3H3 + O2',
#  'C3H2 + O2 => HCCO + HCO',
#  'HCCO + HCO => C3H2 + O2',
#  'C3H4-A + HO2 => C2H4 + CO + OH',
#  'C2H4 + CO + OH => C3H4-A + HO2',
#  'C3H4-A + HO2 => C3H3 + H2O2',
#  'C3H3 + H2O2 => C3H4-A + HO2',
#  'C2H2 + CH3 => C3H4-P + H',
#  'C3H4-P + H => C2H2 + CH3',
#  'C2H2 + CH3 => C3H4-A + H',
#  'C3H4-A + H => C2H2 + CH3',
#  'C3H3 + H => C3H2 + H2',
#  'C3H2 + H2 => C3H3 + H',
#  'C3H2 + OH => C2H2 + HCO',
#  'C2H2 + HCO => C3H2 + OH',
#  'C3H2 + O2 => CO + H + HCCO',
#  'CH3CHCO + OH => C2H5 + CO2',
#  'CH3CHCO + H => C2H5 + CO',
#  'CH3CHCO + O => CH3CHO + CO',
#  'NC3H7O2 => NC3H7 + O2',
#  'NC3H7 + O2 => NC3H7O2',
#  'IC3H7O2 => IC3H7 + O2',
#  'IC3H7 + O2 => IC3H7O2',
#  'C3H5O => C2H3CHO + H',
#  'C2H3CHO + H => C3H5O',
#  'C3H5O => C2H3 + CH2O',
#  'C2H3 + CH2O => C3H5O',
#  'C3H5O + O2 => C2H3CHO + HO2',
#  'C2H3CHO + HO2 => C3H5O + O2',
#  'IC3H7O2 => C3H6 + HO2',
#  'C3H6 + HO2 => IC3H7O2',
#  'NC3H7O2 => C3H6 + HO2',
#  'C3H6 + HO2 => NC3H7O2',
#  'PC4H9 => C2H4 + C2H5',
#  'C2H4 + C2H5 => PC4H9',
#  'SC4H9 => C3H6 + CH3',
#  'C3H6 + CH3 => SC4H9',
#  'PC4H9 => C4H8-1 + H',
#  'C4H8-1 + H => PC4H9',
#  'SC4H9 => C4H8-1 + H',
#  'C4H8-1 + H => SC4H9',
#  'O2 + PC4H9 => C4H8-1 + HO2',
#  'C4H8-1 + HO2 => O2 + PC4H9',
#  'O2 + SC4H9 => C4H8-1 + HO2',
#  'C4H8-1 + HO2 => O2 + SC4H9',
#  'C4H8-1 => C3H5-A + CH3',
#  'C3H5-A + CH3 => C4H8-1',
#  'C4H8-1 => C2H3 + C2H5',
#  'C2H3 + C2H5 => C4H8-1',
#  'C4H8-1 => C4H71-3 + H',
#  'C4H71-3 + H => C4H8-1',
#  'C4H8-1 + O2 => C4H71-3 + HO2',
#  'C4H71-3 + HO2 => C4H8-1 + O2',
#  'C4H8-1 + H => C4H71-3 + H2',
#  'C4H71-3 + H2 => C4H8-1 + H',
#  'C4H8-1 + OH => C4H71-3 + H2O',
#  'C4H71-3 + H2O => C4H8-1 + OH',
#  'C4H8-1 + CH3 => C4H71-3 + CH4',
#  'C4H71-3 + CH4 => C4H8-1 + CH3',
#  'C4H8-1 + HO2 => C4H71-3 + H2O2',
#  'C4H71-3 + H2O2 => C4H8-1 + HO2',
#  'C4H8-1 + CH3O2 => C4H71-3 + CH3O2H',
#  'C4H71-3 + CH3O2H => C4H8-1 + CH3O2',
#  'C4H8-1 + CH3O => C4H71-3 + CH3OH',
#  'C4H71-3 + CH3OH => C4H8-1 + CH3O',
#  'C3H5-A + C4H8-1 => C3H6 + C4H71-3',
#  'C3H6 + C4H71-3 => C3H5-A + C4H8-1',
#  'C4H6 + C4H8-1 => 2 C4H71-3',
#  '2 C4H71-3 => C4H6 + C4H8-1',
#  'C2H5O2 + C4H8-1 => C2H5O2H + C4H71-3',
#  'C2H5O2H + C4H71-3 => C2H5O2 + C4H8-1',
#  'C4H71-3 => C4H6 + H',
#  'C4H6 + H => C4H71-3',
#  'C2H5 + C4H71-3 => C2H4 + C4H8-1',
#  'C2H4 + C4H8-1 => C2H5 + C4H71-3',
#  'C4H71-3 + CH3O => C4H8-1 + CH2O',
#  'C4H8-1 + CH2O => C4H71-3 + CH3O',
#  'C4H71-3 + O => C2H3CHO + CH3',
#  'C2H3CHO + CH3 => C4H71-3 + O',
#  'C4H71-3 + HO2 => C4H7O + OH',
#  'C4H7O + OH => C4H71-3 + HO2',
#  'C4H71-3 + CH3O2 => C4H7O + CH3O',
#  'C4H7O + CH3O => C4H71-3 + CH3O2',
#  'C3H5-A + C4H71-3 => C3H6 + C4H6',
#  'C3H6 + C4H6 => C3H5-A + C4H71-3',
#  'C4H71-3 + O2 => C4H6 + HO2',
#  'C4H6 + HO2 => C4H71-3 + O2',
#  'C4H71-3 + H => C4H6 + H2',
#  'C4H6 + H2 => C4H71-3 + H',
#  'C2H5 + C4H71-3 => C2H6 + C4H6',
#  'C2H6 + C4H6 => C2H5 + C4H71-3',
#  'C2H3 + C4H71-3 => C2H4 + C4H6',
#  'C2H4 + C4H6 => C2H3 + C4H71-3',
#  'C2H5O2 + C4H71-3 => C2H5O + C4H7O',
#  'C2H5O + C4H7O => C2H5O2 + C4H71-3',
#  'C4H7O => C2H3 + CH3CHO',
#  'C2H3 + CH3CHO => C4H7O',
#  'C4H7O => C2H3CHO + CH3',
#  'C2H3CHO + CH3 => C4H7O',
#  'C4H6 => 2 C2H3',
#  '2 C2H3 => C4H6',
#  'C4H6 + OH => C2H5 + CH2CO',
#  'C2H5 + CH2CO => C4H6 + OH',
#  'C4H6 + OH => C3H5-A + CH2O',
#  'C3H5-A + CH2O => C4H6 + OH',
#  'C4H6 + OH => C2H3 + CH3CHO',
#  'C2H3 + CH3CHO => C4H6 + OH',
#  'C4H6 + O => C2H4 + CH2CO',
#  'C2H4 + CH2CO => C4H6 + O',
#  'C4H6 + O => C3H4-A + CH2O',
#  'C3H4-A + CH2O => C4H6 + O',
#  'C2H3 + C2H4 => C4H6 + H',
#  'C4H6 + H => C2H3 + C2H4',
#  'PC4H9O2 => O2 + PC4H9',
#  'O2 + PC4H9 => PC4H9O2',
#  'PC4H9O2 => C4H8-1 + HO2',
#  'C4H8-1 + HO2 => PC4H9O2',
#  'C2H5COCH2 => C2H5 + CH2CO',
#  'C2H5 + CH2CO => C2H5COCH2',
#  'NC3H7CHO + O2 => HO2 + NC3H7CO',
#  'HO2 + NC3H7CO => NC3H7CHO + O2',
#  'NC3H7CHO + OH => H2O + NC3H7CO',
#  'H2O + NC3H7CO => NC3H7CHO + OH',
#  'H + NC3H7CHO => H2 + NC3H7CO',
#  'H2 + NC3H7CO => H + NC3H7CHO',
#  'NC3H7CHO + O => NC3H7CO + OH',
#  'NC3H7CO + OH => NC3H7CHO + O',
#  'HO2 + NC3H7CHO => H2O2 + NC3H7CO',
#  'H2O2 + NC3H7CO => HO2 + NC3H7CHO',
#  'CH3 + NC3H7CHO => CH4 + NC3H7CO',
#  'CH4 + NC3H7CO => CH3 + NC3H7CHO',
#  'CH3O + NC3H7CHO => CH3OH + NC3H7CO',
#  'CH3OH + NC3H7CO => CH3O + NC3H7CHO',
#  'CH3O2 + NC3H7CHO => CH3O2H + NC3H7CO',
#  'CH3O2H + NC3H7CO => CH3O2 + NC3H7CHO',
#  'NC3H7CO => CO + NC3H7',
#  'CO + NC3H7 => NC3H7CO',
#  'HO2 + TC4H9 => OH + TC4H9O',
#  'OH + TC4H9O => HO2 + TC4H9',
#  'CH3O2 + TC4H9 => CH3O + TC4H9O',
#  'CH3O + TC4H9O => CH3O2 + TC4H9',
#  'IC4H9 => H + IC4H8',
#  'H + IC4H8 => IC4H9',
#  'IC4H9 => C3H6 + CH3',
#  'C3H6 + CH3 => IC4H9',
#  'TC4H9 => H + IC4H8',
#  'H + IC4H8 => TC4H9',
#  'O2 + TC4H9 => HO2 + IC4H8',
#  'HO2 + IC4H8 => O2 + TC4H9',
#  'IC4H9 + O2 => HO2 + IC4H8',
#  'HO2 + IC4H8 => IC4H9 + O2',
#  'IC4H9O2 => IC4H9 + O2',
#  'IC4H9 + O2 => IC4H9O2',
#  'TC4H9O2 => O2 + TC4H9',
#  'O2 + TC4H9 => TC4H9O2',
#  'CH3O2 + TC4H9O2 => CH3O + O2 + TC4H9O',
#  'C2H5O2 + TC4H9O2 => C2H5O + O2 + TC4H9O',
#  '2 TC4H9O2 => O2 + 2 TC4H9O',
#  'HO2 + TC4H9O2 => O2 + OH + TC4H9O',
#  'CH3 + TC4H9O2 => CH3O + TC4H9O',
#  'CH3O + TC4H9O => CH3 + TC4H9O2',
#  'C2H5 + TC4H9O2 => C2H5O + TC4H9O',
#  'C2H5O + TC4H9O => C2H5 + TC4H9O2',
#  'TC4H9 + TC4H9O2 => 2 TC4H9O',
#  '2 TC4H9O => TC4H9 + TC4H9O2',
#  'C3H5-A + TC4H9O2 => C3H5O + TC4H9O',
#  'C3H5O + TC4H9O => C3H5-A + TC4H9O2',
#  'C4H71-3 + TC4H9O2 => C4H7O + TC4H9O',
#  'C4H7O + TC4H9O => C4H71-3 + TC4H9O2',
#  'IC4H7 + TC4H9O2 => IC4H7O + TC4H9O',
#  'IC4H7O + TC4H9O => IC4H7 + TC4H9O2',
#  'TC4H9O => CH3 + CH3COCH3',
#  'CH3 + CH3COCH3 => TC4H9O',
#  'IC3H7CHO => H + TC3H6CHO',
#  'H + TC3H6CHO => IC3H7CHO',
#  'IC3H7CHO => HCO + IC3H7',
#  'HCO + IC3H7 => IC3H7CHO',
#  'HO2 + IC3H7CHO => H2O2 + TC3H6CHO',
#  'H2O2 + TC3H6CHO => HO2 + IC3H7CHO',
#  'IC3H7CHO + OH => H2O + TC3H6CHO',
#  'H2O + TC3H6CHO => IC3H7CHO + OH',
#  'IC4H9O2 => IC4H8O2H-I',
#  'IC4H8O2H-I => IC4H9O2',
#  'IC4H9O2 => HO2 + IC4H8',
#  'HO2 + IC4H8 => IC4H9O2',
#  'TC4H9O2 => HO2 + IC4H8',
#  'HO2 + IC4H8 => TC4H9O2',
#  'IC4H8OOH-IO2 => IC4H8O2H-I + O2',
#  'IC4H8O2H-I + O2 => IC4H8OOH-IO2',
#  'IC4H8OOH-IO2 => IC4KETII + OH',
#  'IC4KETII + OH => IC4H8OOH-IO2',
#  'IC4KETII => C2H5CO + CH2O + OH',
#  'IC4H8O2H-I => C3H6 + CH2O + OH',
#  'IC4H8 => C3H5-T + CH3',
#  'C3H5-T + CH3 => IC4H8',
#  'IC4H8 => H + IC4H7',
#  'H + IC4H7 => IC4H8',
#  'H + IC4H8 => C3H6 + CH3',
#  'C3H6 + CH3 => H + IC4H8',
#  'H + IC4H8 => H2 + IC4H7',
#  'H2 + IC4H7 => H + IC4H8',
#  'IC4H8 + O => CH2CO + 2 CH3',
#  'IC4H8 + O => IC4H7 + OH',
#  'IC4H7 + OH => IC4H8 + O',
#  'CH3 + IC4H8 => CH4 + IC4H7',
#  'CH4 + IC4H7 => CH3 + IC4H8',
#  'HO2 + IC4H8 => H2O2 + IC4H7',
#  'H2O2 + IC4H7 => HO2 + IC4H8',
#  'IC4H8 + O2 => HO2 + IC4H7',
#  'HO2 + IC4H7 => IC4H8 + O2',
#  'C3H5-A + IC4H8 => C3H6 + IC4H7',
#  'C3H6 + IC4H7 => C3H5-A + IC4H8',
#  'C3H5-S + IC4H8 => C3H6 + IC4H7',
#  'C3H6 + IC4H7 => C3H5-S + IC4H8',
#  'C3H5-T + IC4H8 => C3H6 + IC4H7',
#  'C3H6 + IC4H7 => C3H5-T + IC4H8',
#  'IC4H8 + OH => H2O + IC4H7',
#  'H2O + IC4H7 => IC4H8 + OH',
#  'IC4H8 + O => HCO + IC3H7',
#  'HCO + IC3H7 => IC4H8 + O',
#  'CH3O2 + IC4H8 => CH3O2H + IC4H7',
#  'CH3O2H + IC4H7 => CH3O2 + IC4H8',
#  'IC4H7 + O2 => IC3H5CHO + OH',
#  'IC3H5CHO + OH => IC4H7 + O2',
#  'IC4H7 + O2 => CH2O + CH3COCH2',
#  'CH2O + CH3COCH2 => IC4H7 + O2',
#  'IC4H7 + O2 => C3H4-A + CH2O + OH',
#  'IC4H7 + O => H + IC3H5CHO',
#  'H + IC3H5CHO => IC4H7 + O',
#  'IC4H7 => C3H4-A + CH3',
#  'C3H4-A + CH3 => IC4H7',
#  'CH3O2 + IC4H7 => CH3O + IC4H7O',
#  'CH3O + IC4H7O => CH3O2 + IC4H7',
#  'HO2 + IC4H7 => IC4H7O + OH',
#  'IC4H7O + OH => HO2 + IC4H7',
#  'IC4H7O => C3H5-T + CH2O',
#  'C3H5-T + CH2O => IC4H7O',
#  'IC4H7O => IC4H6OH',
#  'IC4H6OH => IC4H7O',
#  'IC4H7O => H + IC3H5CHO',
#  'H + IC3H5CHO => IC4H7O',
#  'IC4H6OH => C3H4-A + CH2OH',
#  'C3H4-A + CH2OH => IC4H6OH',
#  'IC4H7O + O2 => HO2 + IC3H5CHO',
#  'HO2 + IC3H5CHO => IC4H7O + O2',
#  'HO2 + IC4H7O => H2O2 + IC3H5CHO',
#  'H2O2 + IC3H5CHO => HO2 + IC4H7O',
#  'CH3 + IC4H7O => CH4 + IC3H5CHO',
#  'CH4 + IC3H5CHO => CH3 + IC4H7O',
#  'IC4H7O + O => IC3H5CHO + OH',
#  'IC3H5CHO + OH => IC4H7O + O',
#  'IC4H7O + OH => H2O + IC3H5CHO',
#  'H2O + IC3H5CHO => IC4H7O + OH',
#  'H + IC4H7O => H2 + IC3H5CHO',
#  'H2 + IC3H5CHO => H + IC4H7O',
#  'IC3H5CHO + OH => H2O + IC3H5CO',
#  'H2O + IC3H5CO => IC3H5CHO + OH',
#  'HO2 + IC3H5CHO => H2O2 + IC3H5CO',
#  'H2O2 + IC3H5CO => HO2 + IC3H5CHO',
#  'CH3 + IC3H5CHO => CH4 + IC3H5CO',
#  'CH4 + IC3H5CO => CH3 + IC3H5CHO',
#  'IC3H5CHO + O => IC3H5CO + OH',
#  'IC3H5CO + OH => IC3H5CHO + O',
#  'IC3H5CHO + O2 => HO2 + IC3H5CO',
#  'HO2 + IC3H5CO => IC3H5CHO + O2',
#  'H + IC3H5CHO => H2 + IC3H5CO',
#  'H2 + IC3H5CO => H + IC3H5CHO',
#  'IC3H5CO => C3H5-T + CO',
#  'C3H5-T + CO => IC3H5CO',
#  'HO2 + TC3H6CHO => OH + TC3H6OCHO',
#  'OH + TC3H6OCHO => HO2 + TC3H6CHO',
#  'TC3H6OCHO => CH3COCH3 + HCO',
#  'CH3COCH3 + HCO => TC3H6OCHO',
#  'TC3H6CHO => H + IC3H5CHO',
#  'H + IC3H5CHO => TC3H6CHO',
#  'H2 + TC3H6CHO => H + IC3H7CHO',
#  'H + IC3H7CHO => H2 + TC3H6CHO',
#  'IC4H7OOH => IC4H7O + OH',
#  'IC4H7O + OH => IC4H7OOH',
#  'CH2O + TC3H6CHO => HCO + IC3H7CHO',
#  'HCO + IC3H7CHO => CH2O + TC3H6CHO',
#  'IC4H8 + TC3H6CHO => IC3H7CHO + IC4H7',
#  'IC3H7CHO + IC4H7 => IC4H8 + TC3H6CHO',
#  'TC3H6O2CHO => O2 + TC3H6CHO',
#  'O2 + TC3H6CHO => TC3H6O2CHO',
#  'O2 + TC3H6CHO => HO2 + IC3H5CHO',
#  'HO2 + IC3H5CHO => O2 + TC3H6CHO',
#  'O2 + TC3H6CHO => CH3COCH3 + CO + OH',
#  'HO2 + TC3H6CHO => IC3H7CHO + O2',
#  'IC3H7CHO + O2 => HO2 + TC3H6CHO',
#  'CH3 + TC3H6CHO => CH4 + IC3H5CHO',
#  'CH4 + IC3H5CHO => CH3 + TC3H6CHO',
#  'HO2 + IC4H6OH => CH2CCH2OH + CH2O + OH',
#  'CH2CCH2OH + O2 => CH2O + CH2OH + CO',
#  'CH2CCH2OH => C2H2 + CH2OH',
#  'C2H2 + CH2OH => CH2CCH2OH',
#  'CH2CCH2OH => C3H4-A + OH',
#  'C3H4-A + OH => CH2CCH2OH',
#  'C5H10-1 <=> C2H5 + C3H5-A',
#  'C5H91-3 + H <=> C5H10-1',
#  'C5H10-1 + H <=> C5H91-3 + H2',
#  'C5H10-1 + H <=> C5H91-4 + H2',
#  'C5H10-1 + O <=> C5H91-3 + OH',
#  'C5H10-1 + O <=> C5H91-4 + OH',
#  'C5H10-1 + OH <=> C5H91-3 + H2O',
#  'C5H10-1 + OH <=> C5H91-4 + H2O',
#  'C5H10-1 + CH3 <=> C5H91-3 + CH4',
#  'C5H10-1 + CH3 <=> C5H91-4 + CH4',
#  'C5H10-1 + O2 <=> C5H91-3 + HO2',
#  'C5H10-1 + O2 <=> C5H91-4 + HO2',
#  'C5H10-1 + HO2 <=> C5H91-3 + H2O2',
#  'C5H10-1 + HO2 <=> C5H91-4 + H2O2',
#  'C5H10-1 + CH3O2 <=> C5H91-3 + CH3O2H',
#  'C5H10-1 + CH3O2 <=> C5H91-4 + CH3O2H',
#  'C5H10-1 + CH3O <=> C5H91-3 + CH3OH',
#  'C5H10-1 + CH3O <=> C5H91-4 + CH3OH',
#  'C4H6 + CH3 <=> C5H91-3',
#  'C2H3 + C3H6 <=> C5H91-4',
#  'C6H13-1 => C2H4 + PC4H9',
#  'C2H4 + PC4H9 => C6H13-1',
#  'C5H10-1 + OH <=> CH3CHO + NC3H7',
#  'C6H13O2-1 => C6H13-1 + O2',
#  'C6H13-1 + O2 => C6H13O2-1',
#  'NC4H9CHO + O2 => HO2 + NC4H9CO',
#  'HO2 + NC4H9CO => NC4H9CHO + O2',
#  'NC4H9CHO + OH => H2O + NC4H9CO',
#  'H2O + NC4H9CO => NC4H9CHO + OH',
#  'H + NC4H9CHO => H2 + NC4H9CO',
#  'H2 + NC4H9CO => H + NC4H9CHO',
#  'NC4H9CHO + O => NC4H9CO + OH',
#  'NC4H9CO + OH => NC4H9CHO + O',
#  'HO2 + NC4H9CHO => H2O2 + NC4H9CO',
#  'H2O2 + NC4H9CO => HO2 + NC4H9CHO',
#  'CH3 + NC4H9CHO => CH4 + NC4H9CO',
#  'CH4 + NC4H9CO => CH3 + NC4H9CHO',
#  'CH3O + NC4H9CHO => CH3OH + NC4H9CO',
#  'CH3OH + NC4H9CO => CH3O + NC4H9CHO',
#  'CH3O2 + NC4H9CHO => CH3O2H + NC4H9CO',
#  'CH3O2H + NC4H9CO => CH3O2 + NC4H9CHO',
#  'NC4H9CO => CO + PC4H9',
#  'CO + PC4H9 => NC4H9CO',
#  'NC7H16 => C7H15-1 + H',
#  'C7H15-1 + H => NC7H16',
#  'NC7H16 => C7H15-2 + H',
#  'C7H15-2 + H => NC7H16',
#  'NC7H16 => C7H15-3 + H',
#  'C7H15-3 + H => NC7H16',
#  'NC7H16 => C7H15-4 + H',
#  'C7H15-4 + H => NC7H16',
#  'NC7H16 (+M) <=> C6H13-1 + CH3 (+M)',
#  ...]

# %% [markdown]
# That is quite a long list! The equation for a specific reaction can be listed with the
#
# ``` python
# reaction_equation(rxn_number)
#     ```
# function, where the integer input refers to the number of the reaction in the list.

# %%
gas.reaction_equation(11)
# Out:
# '2 O + M => O2 + M'

# %% [markdown]
# The type of the reaction can be examine with
#
# ```python
# reaction_type(rxn_number)
# ```
#  function.  This function will provide an integer.  The meaning of this integer is shown in the table below.
#
# | Reaction Type Integer | Reaction Type | Example |
# | ---------- | ---- | ---- |
# | 1 | Elementary | H + O $\leftrightarrow$ OH |
# | 2 | Three Body | H + H + M $\leftrightarrow$ H2 + M |
# | 4 | Fall Off   | CH3 + H (+M) $\leftrightarrow$  CH4 (+M) |
# | 8 | Chemically Activated Bimolecular | Si + SiH4 (+M) $\leftrightarrow$ Si2H2 + H2 (+M) |

# %%
gas.reaction_type(11)
# Out:
# 2

# %% [markdown]
# ### Reaction Rates Constants

# %% [markdown]
# The forward and reverse rate constants for all reactions be accessed with
# ```python
#    .forward_rate_constants
#    .reverse_rate_constants
# ```
# arrays.  Both of these are arrays return the rate constant for each reaction on a **molar** basis.  The precise units are dependent on the overrall order of the reaction.  The order of the list corresponds to the order in the full reaction equation list.

# %%
gas.forward_rate_constants
# Out:
# array([2.82683727e-01, 1.17842545e+10, 5.44691431e+03, ...,
#        5.51956920e-06, 1.33780253e-13, 9.51785220e-14])

# %% [markdown]
# A rate constant for specific reaction in the array can be accessed with the particular element.

# %%
kf=gas.forward_rate_constants[11]
kr=gas.reverse_rate_constants[11]
print('for ', gas.reaction_equation(11), ': kf = ', kf, 'kr = ', kr)
# Out:
# for  2 O + M => O2 + M : kf =  14458845.803240841 kr =  0.0

# %% [markdown]
# ### Reaction Rates of Progress

# %% [markdown]
# the forward, reverse, and net rate of progress on a **molar** basis for all reactions can be accessed by the arrays:
#
# ```python
# forward_rates_of_progress
# reverse_rates_of_progress
# net_rates_of_progress
# ```
# The units are *always* kmol/m$^3$ s.

# %%
gas.TPX = 1500, 101325, {'CO2':1}
RRf = gas.forward_rates_of_progress[11]
RRr = gas.reverse_rates_of_progress[11]
RRn = gas.net_rates_of_progress[11]

print('for ', gas.reaction_equation(11), ': RRf = ', RRf, 
      'RRr = ', RRr, 'RR net = ', RRn, ' kmol/m^3 s')
# Out:
# for  2 O + M => O2 + M : RRf =  0.0 RRr =  0.0 RR net =  0.0  kmol/m^3 s

# %% [markdown]
# ### Molar Rates Production

# %% [markdown]
# The molar rates of production for each species can be accessed by the following arrays:
#
# ```python
# creation_rates
# destruction_rates
# net_production_rates
# ```
# The units are always on a **molar** basis with *kmol/m$^3$ s*.
#
#
# The full array of each net production rate for each species is

# %%
gas.net_production_rates
# Out:
# array([ 0.00000000e+00,  0.00000000e+00,  6.42148588e-09,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         6.42148588e-09, -6.42148588e-09,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00])

# %% [markdown]
# The production rate for a particular species can be accessed using its species index.

# %%
nCO2 = gas.species_index('CO2')
cRate = gas.creation_rates[nCO2]
dRate = gas.destruction_rates[nCO2]
pRate = gas.net_production_rates[nCO2]

print('The CO2 rate of creation, destruction, and net production are', cRate, dRate, pRate, 'kmol/m^3 s')
# Out:
# The CO2 rate of creation, destruction, and net production are 0.0 6.421485882566368e-09 -6.421485882566368e-09 kmol/m^3 s

# %% [markdown]
# The mass production rate for each species can be computed via:
#
# $\dot{\omega}_i = \overline{\dot{\omega}}_i MW_i$

# %%
MW_CO2 = gas.molecular_weights[nCO2]
omegaBar_CO2 = gas.net_production_rates[nCO2]

print('The net mass production rate of CO2 is', MW_CO2*omegaBar_CO2, 'kg/m$^3$ s')
# Out:
# The net mass production rate of CO2 is -2.826031722058633e-07 kg/m$^3$ s

# %% [markdown]
# Lets equilibrate the mixture and ensure that the net molar rates of production are effectively zero.

# %%
gas.equilibrate('HP')
print(gas.net_production_rates)
# Out:
# [ 0.00000000e+00  0.00000000e+00  2.66767872e-11 -2.66982211e-11
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -2.67196551e-11  2.67196551e-11  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00]

# %% [markdown]
# ## Constant Volume Adiabatic Reactor

# %% [markdown]
# In class we will show that the differential equations describing the evolution of species mass fractions and temperature for constant volume adiabatic reactor are:
#
# $\frac{d Y_i}{dt} =\frac{\dot{\omega_i}}{\rho}, \ \ \ i = 1, \cdots N$
#
# $\frac{d T}{dt} = \frac{- \sum u_i \dot{\omega}_i}{\rho Cv_{\text{mix}}}$
#
# These equations will be integrated using the stiff ODE solver from Python and Cantera to evaluate the net rate of production for each species, internal energies for each species, and the mixture specific heat.  An issue to be aware of is that Cantera returns the species rate of production only on a molar basis.  However,
#
# $\overline{u}_i = u_i MW_i; \ \ \ \overline{\dot{\omega}}_i = \dot{\omega}_i/MW_i$,
#
# Thus
#
# $ u_i \dot{\omega}_i = \overline{u}_i \overline{\dot{\omega}}_i$,
#
# and the temperature and mass fraction equations that we will actually solve is
#
# $\frac{d T}{dt} = \frac{- \sum \overline{u}_i \overline{\dot{\omega}}_i}{\rho Cv_{\text{mix}}}$
#
# $\frac{d Y_i}{dt} =\frac{\overline{\dot{\omega}_i} MW_i}{\rho}, \ \ \ i = 1, \cdots N$
#
# To solve the system of ODEs for the constant volume reactor, we first must define a function that computes the time derivatives for the mass fractions and temperature.  (The below function looks long, but most of the lines are comments. There are only 13 active lines of code.)

# %% [markdown]
# ## 3.2 - Constant volume reactant code

# %%
def CV_Reactor_RHS(t,y,gas,density):
    # t = time
    # y = the solution vector: y[0] = temperature, y[1:nSpecies] = mass fractions
    
    dy = np.zeros(np.size(y)) # initialize the RHS vector
    
    
    # get T and Y_i from the solution vector.
    # T is the first (0) index of the solution array y[0]
    # all indexes after 0, y[1:], are the mass fractions
    T = y[0];
    massFrac = y[1:];

    # Now we set the species composition.  Here we use a special version that 
    # does not normalize the mass fractions to sum to unity.  Solving systems
    # of ODEs like this are one of the few cases where you do not want
    # to normalize the mass fractions.  
    
    # Swagnik, in case you get a question: This has to do with computing the
    # Jacobian using finite differences.  If Y_i were normalized than perturbing one
    # will perturb all of the others, which messes up the Jacobian computation. 
    gas.set_unnormalized_mass_fractions(massFrac)
    
    # set the state using the density (density is constant for this case, 
    # but pressure is not.  So we have to set the thermodynamic state using 
    # the temperature and density. )
    gas.TD=T, density #gas.density_mass
    

    

    # Now that the thermodynamic state is set, we can compute the chemical
    # rate of production, species internal energies, cv, etc. 
    wdot = gas.net_production_rates      # get the species MOLAR production rate
    mws  = gas.molecular_weights         # get the species MW_i
    ui = gas.partial_molar_int_energies  # get the species internal energy on a MOLAR basis
    cv = gas.cv_mass                     # get the mixture CV on a MASS basis
        
    # form the RHS for a CV adiabatic reactor
    dTdt = -np.sum(wdot*ui)/(density*cv)   # the sum function sums elements over an array
                                           # you don't need the .* as in Matlab
    dYdt = wdot*mws/density
    
    # stuff the temperature and mass fraction time derivatives into an array
    dy[0 ] = dTdt
    dy[1:] = dYdt
    
    return dy

# %% [markdown]
# For convenience, we will define a function that integrates the CV reactor.  Similar to the equilibrate function, the initial conditions are set based on the gas state that is an input to the function

# %%
def integrate_CV_reactor(gas, tEnd,atol=1.e-10, rtol=1.e-8):
    rho = gas.density_mass # compute the density on a mass basis

    # set the initial conditions for the reactor
    y =  np.zeros(gas.n_species+1) 
    y[0] = gas.T
    y[1:] = gas.Y

    # solve the ODEs for the CV reactor.  This is equivalent to ode15s in Matlab.
    soln = integrate.solve_ivp(fun=lambda t, y: CV_Reactor_RHS(t,y,gas,rho), 
                               t_span=[0,tEnd],y0=y,method='BDF',rtol=rtol,atol=atol);
    return soln

# %% [markdown]
# Now we integrate a CV reactor with a stochiometric mixture of methane and oxygen at 1500 K and 1 atm.

# %%
def P_heat_release_CV_Reactor(soln, gas):
    # Compute the pressure and rate of heat release based on the solution
    # to a CV reactor
    
    # find the number of time points and pre-allocate an array
    npt = len(soln.t)
    p_hr = np.zeros((2,npt))
    
    # loop over over each time, set the gas composition and compute the pressure.  
    for i in range(npt):
        # set the gas composition.  Note: the y[1:,i] grabs all elements in the array after 1
        gas.TDY = soln.y[0,i], gas.density_mass, soln.y[1:,i] 
        p = gas.P # compute the pressure
        
        # compute the chemical heat release rate
        hr = -np.sum(gas.net_production_rates*gas.partial_molar_int_energies)
        
        # store the pressure and heat release rate
        p_hr[0,i] = p
        p_hr[1,i] = hr
        
    return p_hr

def compute_CV_ignition_delay(gas,soln, tShift = 600.):
    # compute the ignition delay time from the solution to a CV reactor.  
    # this is (crudely) based on the time when the temperatur increases 
    # by a specified value from the initial reactant temperature
    npt = len(soln.t)    
    tInit = soln.y[0,0]
    
    for i in range(npt):
        if (soln.y[0,i] > tInit + tShift):
            break
            
    t_ign = soln.t[i]
    
    return t_ign

# %%
# Ignition delay time 
# Set the pressure and temp 

p_init = 101325*40
temp_start= 600
temp_end= 1500

# temparature array 
npts = 30

tInit = np.linspace(temp_start, temp_end,npts)
tIgn = np.zeros(npts)

for i in range(npts):
    #print(i)
    # The initial conditions are based on the gas state.
    #gas.TPX = tInit[i], p_init, {'NC7H16':0,'IC8H18':1, 'O2':0.3} #PRF 0
    gas.TPX = tInit[i], p_init, {'NC7H16':0.5,'IC8H18':0.5, 'O2':0.3} #PRF 50
    #gas.TPX = tInit[i], p_init, {'NC7H16':1,'IC8H18':0, 'O2':0.3} #PRF 100


# now integrate the ODEs
    soln = integrate_CV_reactor(gas, 30.)

    if (i%5 == 0):
        plt.semilogx(soln.t,soln.y[0,:],label='Temp= %d K'%tInit[i])
    
    tIgn[i] = compute_CV_ignition_delay(gas,soln, tShift = 600.)

plt.xlabel('time (s)')
plt.ylabel('Temperature (K)')
plt.legend()
plt.show()

# %%
t_tange=[775,1225,1700]
gas.TPX = tInit[i], p_init, {'NC7H16':0.5,'IC8H18':0.5, 'O2':0.3} #PRF 50


# The initial conditions are based on the gas state.

gas.TPX = 600, 101325*40, {'NC7H16':0.5,'IC8H18':0.5, 'O2':0.3} # PRF -50

print(gas.density_mass, gas.P)

# now integrate the ODEs
soln = integrate_CV_reactor(gas, 30.)
# Out:
# 73.00577418669536 4053000.0000000005

# %% [markdown]
# The cell below defines integers that access selected variables in the solution array from that CV reactor solution.  A variable can be accessed by:
#
# ```python
# soln.y[variable_index, time_index]
# ```
#
# The time can be accessed by:
#
# ```python
# soln.t[time_index]
# ```
#
# All of the times can be accessed using the colon operator (similar to matlab)
#
# ```python
# soln.t[:]
# soln.y[variable_index,:]
#    ```
#
# The variable indexes are:
#
# | variable index | variable |
# | --- | --- |
# | 0 | Temperature |
# | 1 | Species 0 |
# | 2 | Species 1 |
# | 3 | Species 2 |
# | ... | ... |
# | N+1 | Species N |
#
# the variable index for a particular species can be found by:
#
# ```python
# species_variable_index = gas.species_index(species_name) + 1
#     ```
#
# Below we define some variable indices for plotting the solution.

# %%
temp_index = 0
nHeptane_index = gas.species_index('NC7H16')+1
isoOctane_index = gas.species_index('IC8H18')+1
H2O2_index = gas.species_index('H2O2') + 1
CH3_index = gas.species_index('CH3') + 1
H_index = gas.species_index('H') + 1
OH_index = gas.species_index('OH') + 1 
CO_index = gas.species_index('CO') + 1
H2O_index = gas.species_index('H2O') + 1
CO2_index = gas.species_index('CO2') + 1
O2_index = gas.species_index('O2') + 1

# %%
# Now plot the solution.  Note: Cantera works in SI units, but I convert to ms in the line below. 
plt.semilogx(soln.t*1000, soln.y[temp_index,:])
plt.xlabel('time (ms)')
plt.ylabel('Temperature (K)')
plt.show()


# The first plot isn't very useful... even on a semilogx-scale... Lets zoom in to where the action is. 
plt.plot(soln.t*1000, soln.y[temp_index,:])
plt.xlim(100, 200)
plt.xlabel('time (ms)')
plt.ylabel('Temperature (K)')
plt.show()

# %%
plt.semilogy(soln.t*1000,soln.y[OH_index,:], label = 'OH')
plt.semilogy(soln.t*1000, soln.y[H2O_index,:], label = 'H$_2$O')
plt.semilogy(soln.t*1000, soln.y[CO2_index,:], label = 'CO$_2$')
plt.semilogy(soln.t*1000, soln.y[O2_index,:],  label = 'O$_2$')
plt.semilogy(soln.t*1000, soln.y[nHeptane_index,:], label = 'n-$C_7H_{16}$')
# For annotating the plot, please use either a legend or annotatations
plt.legend(loc="best", bbox_to_anchor=[.9, .5],
           ncol=1, shadow=True,  fancybox=True,fontsize='medium')
plt.xlim(100, 200)
plt.ylim(1.E-13, 0.1)
plt.xlabel('time (ms)')
plt.ylabel('mass fraction')
plt.show()

# %% [markdown]
# ### Other Diagnostics for Reactors

# %% [markdown]
# Somtimes it is desirable to compute the pressure, the heat release rate, or the ignition delay time for the constant volume reactor.  Below are some post-processing functions that are defined for this purpose.

# %% [markdown]
# Now we use the solution computed above and our post-processing functions to compute the pressure and ignition delay time for the reactor.

# %%
# Compute the pressure and heat release based on the solution to the CV reactor
p_hr = P_heat_release_CV_Reactor(soln, gas)
plt.plot(soln.t*1000, p_hr[0,:]/101325)
plt.xlim(100, 200)
plt.xlabel('time (ms)')
plt.ylabel('Pressure (atm)')
plt.show()

plt.plot(soln.t*1000, p_hr[1,:]/1E6)
plt.xlim(100, 200)
plt.xlabel('time (ms)')
plt.ylabel('heat release rate (MJ/s m$^3$)')
plt.show()

# %%
tIgn = compute_CV_ignition_delay(gas,soln, tShift = 600.)
print('The ignition delay time is ', tIgn*1000, ' ms')
# Out:
# The ignition delay time is  30000.0  ms

# %% [markdown]
# Below is an example of sweeping over a range of initial temperatures to find the ignition delay time as a function of initial temperature. The following loop can take quite awhile to execute so be patient.   The results are plotted on an Arrhenius-style plot.  The temperature-time trace is also plotted for several initial temperatures.
